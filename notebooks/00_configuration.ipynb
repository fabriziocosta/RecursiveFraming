# %% [markdown]
# # Shared notebook configuration
#
# This is the first notebook in the workflow. Edit `configs/notebook_config.yaml` to change parameters; the numbered notebooks load their own section from that file. Sections are grouped by the notebook that consumes them: PubMed discovery, PubMed corpus collection, pathogen categorization, ontology assembly, single-abstract graphicalization, and batch graphicalization.
#
# Credentials are intentionally not stored in YAML. The configuration names the environment variables used for the PubMed and OpenAI keys.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'assets').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / 'assets').exists():
    raise FileNotFoundError('Could not locate the repository assets directory.')
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from graphicalizer.notebook_config import CONFIG_RELATIVE_PATH, load_notebook_config

CONFIG_PATH = PROJECT_ROOT / CONFIG_RELATIVE_PATH
CONFIG = load_notebook_config(PROJECT_ROOT)
print(f'Loaded configuration: {CONFIG_PATH}')
print('Notebook sections:')
for section in CONFIG:
    print(f'  - {section}')

# %%
from pprint import pprint

pprint(CONFIG)
